# %% [markdown]
# # First Step: Round 1
#
# This queries Google Scholar for the three 'seed' papers, collects the first 300 'related articles' from them, and filters out the unique 'Well Cited Papers' from them, saving the result as a spreadsheet for dual coding.
#
# Note that it requires a SerpAPI.com API key; a free two-week trial account is currently available.

# %%
# !pip install google-search-results
from serpapi import GoogleScholarSearch, GoogleSearch
import pandas as pd
import numpy as np
from ScholarUtils import GetPapers, GetPaper, WellCitedPapers, InitScholar, RelatedQuery
# Reload ScholarUtils every time before executing code 
# %reload_ext autoreload
# %autoreload 2

# %%
InitScholar("APIKey.yaml")

# %%
initialPaperSearches=[
    'Software engineering for security: a roadmap PT Devanbu',
    'You Get Where You’re Looking For: The Impact of Information Sources on Code Security, Acar et al',
    'A Survey on Developer-Centred Security, by Tahaei & Vaniea'
]

# %%
initialPapers=[GetPaper({'q': search}) for search in initialPaperSearches]
# Out:
# GetPaper:{'q': 'Software engineering for security: a roadmap PT Devanbu'}
# GetPaper:{'q': 'You Get Where You’re Looking For: The Impact of Information Sources on Code Security, Acar et al'}
# GetPaper:{'q': 'A Survey on Developer-Centred Security, by Tahaei & Vaniea'}

# %%
initialPapersDf=WellCitedPapers(initialPapers) # Includes the Related, which is what we want
initialPapersDf['Round']=1 # all ones.
initialPapersDf
# Out:
#                     Key  Citations  Year  \
# 0  17567618191233461182        645  2000
# 1   7379463099867128855        188  2016
# 2   3515120953808077324         21  2019
#
#                                                Title  \
# 0       Software engineering for security: a roadmap
# 1  You get where you're looking for: The impact o...
# 2             A Survey on Developer-Centred Security
#
#                             Authors  \
# 0         PT Devanbu, S Stubblebine
# 1  Y Acar, M Backes, S Fahl, D Kim…
# 2                M Tahaei, K Vaniea
#
#                                                 Link       Related  \
# 0   https://dl.acm.org/doi/abs/10.1145/336512.336559  visp7qq3zPMJ
# 1  https://ieeexplore.ieee.org/abstract/document/...  F-SuXJceaWYJ
# 2  https://ieeexplore.ieee.org/abstract/document/...  DEJDMuI3yDAJ
#
#                                              Snippet  Round
# 0  Is there such a thing anymore as a software sy...      1
# 1  Vulnerabilities in Android code--including but...      1
# 2  Software developers are key players in the sec...      1

# %%
allPapers = [foundPaper for relatedPaper in initialPapersDf.itertuples()
                 for foundPaper in GetPapers(RelatedQuery(relatedPaper.Related))
            ] # Concatenate returned lists...
print(len(allPapers))
firstCutRelatedDf=(WellCitedPapers(allPapers)
                   .assign(Round=2)
                  )
firstCutRelatedDf
# Out:
# Retrieving 101 papers for {'q': 'related:visp7qq3zPMJ:scholar.google.com/'}
# Retrieving 101 papers for {'q': 'related:F-SuXJceaWYJ:scholar.google.com/'}
# Retrieving 101 papers for {'q': 'related:DEJDMuI3yDAJ:scholar.google.com/'}
# 303
#                       Key  Citations  Year  \
# 0    17567618191233461182        645  2000
# 1    12813600874337390632        613  1999
# 2    11287243237506407833        944  2002
# 3    17600728651530679484       1060  2002
# 4    15499650706254585718       1378  2005
# ..                    ...        ...   ...
# 124  16879893825225754361         61  2018
# 125   4325511156220754863         21  2019
# 126  14295319890240191588          9  2019
# 127  11415931451330937671         10  2020
# 128   7695395392452979437         43  2017
#
#                                                  Title  \
# 0         Software engineering for security: a roadmap
# 1    Using abuse case models for security requireme...
# 2    UMLsec: Extending UML for secure systems devel...
# 3    SecureUML: A UML-based modeling language for m...
# 4    Eliciting security requirements with misuse cases
# ..                                                 ...
# 124     Security in the software development lifecycle
# 125  " If you want, I can store the encrypted passw...
# 126  DevOps, a new approach to cloud development & ...
# 127  Understanding privacy-related questions on Sta...
# 128                       Just-in-time static analysis
#
#                                            Authors  \
# 0                        PT Devanbu, S Stubblebine
# 1                               J McDermott, C Fox
# 2                                        J Jürjens
# 3                  T Lodderstedt, D Basin, J Doser
# 4                              G Sindre, AL Opdahl
# ..                                             ...
# 124                            H Assal, S Chiasson
# 125           A Naiakshina, A Danilova, E Gerlitz…
# 126                             P Agrawal, N Rawat
# 127                   M Tahaei, K Vaniea, N Saphra
# 128  LNQ Do, K Ali, B Livshits, E Bodden, J Smith…
#
#                                                   Link       Related  \
# 0     https://dl.acm.org/doi/abs/10.1145/336512.336559  visp7qq3zPMJ
# 1    https://ieeexplore.ieee.org/abstract/document/...  KNCDGBsO07EJ
# 2    https://link.springer.com/chapter/10.1007/3-54...  md3_EOxXpJwJ
# 3    https://link.springer.com/chapter/10.1007/3-54...  vLSGtnRZQvQJ
# 4    https://link.springer.com/content/pdf/10.1007/...  dt_vWDLSGdcJ
# ..                                                 ...           ...
# 124  https://www.usenix.org/conference/soups2018/pr...  -QbkIgBuQeoJ
# 125  https://dl.acm.org/doi/abs/10.1145/3290605.330...  r_uGonpNBzwJ
# 126  https://ieeexplore.ieee.org/abstract/document/...  ZLxXSLMtY8YJ
# 127  https://dl.acm.org/doi/abs/10.1145/3313831.337...  R0PKuCuJbZ4J
# 128  https://dl.acm.org/doi/abs/10.1145/3092703.309...  7WpWZVaJy2oJ
#
#                                                Snippet  Round
# 0    Is there such a thing anymore as a software sy...      2
# 1    The relationships between the work products of...      2
# 2    Developing secure-critical systems is difficul...      2
# 3    We present a modeling language for the model-d...      2
# 4    Use cases have become increasingly common duri...      2
# ..                                                 ...    ...
# 124  We interviewed developers currently employed i...      2
# 125  In 2017 and 2018, Naiakshina et al.(CCS'17, SO...      2
# 126  Organization's proficiency to deliver services...      2
# 127  ABSTRACT We analyse Stack Overflow (SO) to und...      2
# 128  We present the concept of Just-In-Time (JIT) s...      2
#
# [129 rows x 9 columns]

# %%
['Charles','Pierre','AgreedScore']+list(initialPapersDf.columns.values)
# Out:
# ['Charles',
#  'Pierre',
#  'AgreedScore',
#  'Key',
#  'Citations',
#  'Year',
#  'Title',
#  'Authors',
#  'Link',
#  'Related',
#  'Snippet',
#  'Round']

# %%
allPapersSoFarDf=(pd.concat([initialPapersDf, firstCutRelatedDf]) 
                .drop_duplicates(subset=['Key'])
                .reindex(columns=list(initialPapersDf.columns.values)+['Charles','Pierre','AgreedScore'],fill_value='')
               )
print(len(allPapersSoFarDf))
allPapersSoFarDf.to_excel('PapersToCode.xlsx')
allPapersSoFarDf
# Out:
# 126
#                       Key  Citations  Year  \
# 0    17567618191233461182        645  2000
# 1     7379463099867128855        188  2016
# 2     3515120953808077324         21  2019
# 1    12813600874337390632        613  1999
# 2    11287243237506407833        944  2002
# ..                    ...        ...   ...
# 121   6285781247893872317          5  2020
# 123   5117288349966358717         35  2018
# 126  14295319890240191588          9  2019
# 127  11415931451330937671         10  2020
# 128   7695395392452979437         43  2017
#
#                                                  Title  \
# 0         Software engineering for security: a roadmap
# 1    You get where you're looking for: The impact o...
# 2               A Survey on Developer-Centred Security
# 1    Using abuse case models for security requireme...
# 2    UMLsec: Extending UML for secure systems devel...
# ..                                                 ...
# 121  Interventions for long‐term software security:...
# 123  Why developers cannot embed privacy into softw...
# 126  DevOps, a new approach to cloud development & ...
# 127  Understanding privacy-related questions on Sta...
# 128                       Just-in-time static analysis
#
#                                            Authors  \
# 0                        PT Devanbu, S Stubblebine
# 1                 Y Acar, M Backes, S Fahl, D Kim…
# 2                               M Tahaei, K Vaniea
# 1                               J McDermott, C Fox
# 2                                        J Jürjens
# ..                                             ...
# 121            C Weir, I Becker, J Noble, L Blair…
# 123                   A Senarath, NAG Arachchilage
# 126                             P Agrawal, N Rawat
# 127                   M Tahaei, K Vaniea, N Saphra
# 128  LNQ Do, K Ali, B Livshits, E Bodden, J Smith…
#
#                                                   Link       Related  \
# 0     https://dl.acm.org/doi/abs/10.1145/336512.336559  visp7qq3zPMJ
# 1    https://ieeexplore.ieee.org/abstract/document/...  F-SuXJceaWYJ
# 2    https://ieeexplore.ieee.org/abstract/document/...  DEJDMuI3yDAJ
# 1    https://ieeexplore.ieee.org/abstract/document/...  KNCDGBsO07EJ
# 2    https://link.springer.com/chapter/10.1007/3-54...  md3_EOxXpJwJ
# ..                                                 ...           ...
# 121  https://onlinelibrary.wiley.com/doi/abs/10.100...  vZ6G0L2UO1cJ
# 123  https://dl.acm.org/doi/abs/10.1145/3210459.321...  vVj9SKRCBEcJ
# 126  https://ieeexplore.ieee.org/abstract/document/...  ZLxXSLMtY8YJ
# 127  https://dl.acm.org/doi/abs/10.1145/3313831.337...  R0PKuCuJbZ4J
# 128  https://dl.acm.org/doi/abs/10.1145/3092703.309...  7WpWZVaJy2oJ
#
#                                                Snippet  Round Charles Pierre  \
# 0    Is there such a thing anymore as a software sy...      1
# 1    Vulnerabilities in Android code--including but...      1
# 2    Software developers are key players in the sec...      1
# 1    The relationships between the work products of...      2
# 2    Developing secure-critical systems is difficul...      2
# ..                                                 ...    ...     ...    ...
# 121  Though some software development teams are hig...      2
# 123  Pervasive use of software applications continu...      2
# 126  Organization's proficiency to deliver services...      2
# 127  ABSTRACT We analyse Stack Overflow (SO) to und...      2
# 128  We present the concept of Just-In-Time (JIT) s...      2
#
#     AgreedScore
# 0
# 1
# 2
# 1
# 2
# ..          ...
# 121
# 123
# 126
# 127
# 128
#
# [126 rows x 12 columns]

# %%
# !open PapersToCode.xlsx
